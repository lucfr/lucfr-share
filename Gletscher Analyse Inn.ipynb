# %% [markdown]
# # Gletscher im Inn Einzugsgebiet und ihr Einfluss auf die Sedimentfrachten

# %% [markdown]
# ![Gletscherbedeckung Alpen](Überblick_über_die_Gletscherbedeckung_und_die_Gletschermassenbilanz_in_den_Europäischen_Alpen.jpg)

# %% [markdown]
# ![Gletscherbedeckung MoRE](AUs_Inn_Gletscher_highsedezgs_small.png)

# %% [markdown]
# #### Problem, Fragestellung:
#
# Sedimentfrachten bei einigen Pegeln deutlich über dem berechneten Bodenabtrag. Ursache aus den gegeben Daten nicht erkennbar.
#
# ![ER vs Sed](ER_vs_Sed.png)

# %% [markdown]
# Abbildungen Regr Flächen etc:

# %% [markdown]
# Abbildungen Pegel cumsum: Schlussfolgerungen aus dem Anstieg? vs Abfluss, vs Precip?

# %% [markdown]
# Geologie, Boden
#
# Post-glaziale Flächen = Raster aus offene Flächen > 1000m? testen testen testen

# %% [markdown]
# ### Bruchkäusel, Brixenthaler Ache
#
# ##### Mögliche Gründe für hohe Frachten:
#
# Die Talfluchten verlaufen zwar von Westen nach Osten, die Flüsse aber durchbrechen die vorhergehenden Bergketten und entwässern heute nach Norden. Des Weiteren fällt das Brixental von Kirchberg bis Hopfgarten gänzlich in die **Schiefer der Grauwackenzone**. Dabei spielt die Tektonik möglicherweise eine größere Rolle. Auch die Triaskalke am Gaisberg sind sehr auffällig. Außerdem ist **das Gestein der Schieferzonen sehr leicht abtragbar und kann von Wasser leicht geschliffen werden**. Letztlich haben **auch noch die Gletscher zur Talformung beigetragen**. Ursprünglich würde die Brixentaler Ache Richtung Kirchberg in Tirol, über Reith bei Kitzbühel, Going nach St. Johann fließen, da damals der Gletscherast von den Hohen Tauern Richtung Norden entwässerte. Außerdem staute ein Gletschervorstoß vor etwa 15.000 Jahren aus der Windau die Brixentaler Ache auf, sodass diese in Kirchberg die Aschauer Ache speiste. Eine genauere Untersuchung zeigte jedoch, dass die Ansiedlung von Kirchberg die Talwasserscheide beeinträchtige und formte. Quelle: [Wikipedia](https://www.wikiwand.com/de/Spertendorf)

# %% [markdown]
# ### Kössen-Hütte, Großache
#
# Die Gesteine stammen aus der Zeit des Erdaltertums (Paläozoikum). Dabei handelt es sich um Gesteine des unterostalpinen Innsbrucker Quarzphyllits, des mittelostalpinen Kellerjochgneises und um die Sedimentgesteine der oberostalpinen Grauwackenzone (Schwazer Dolomit/ Spielbergdolomit, Wildschönauer Schiefer).
# Im Wesentlichen handelt es sich dabei um phyllitischschiefrige Gesteine **mit hohem Anteil an Tonmineralen**. **Durch diese Zusammensetzung sind diese Gesteine sehr verwitterungsanfällig, wodurch sich die eher weichen Landschaftsformen und der weitgehend geschlossene Bewuchs der Berge erklären lässt**. Im Unterschied dazu bilden die Gesteine des Schwazer Dolomits/Spielbergdolomits als typische Karbonatgesteine meist schroffe Landschaftsformen. Diese bilden den Rest des Einzugsgebietes nach Norden. Bemerkenswert sind dabei **die meist rötlichen, tonsteinreichen Sandsteinablagerungen des Buntsandsteins**, die im Raum Ellmau - St. Johann – Hochfilzen in den tieferen Hangbereichen für weiche Landschaftsformen und guten Bewuchs sorgen. Gegen Norden setzen über diese Sandsteine die meist schroffen Kalk- und Dolomitgesteine des Kaisergebirges, der Loferer Steinberge, der Waidringer Steinplatte und umliegender Berge ein. Steile Felsformationen prägen das Landschaftsbild, dessen Reiz die **immer wieder auftretende Einschaltung tonsteinreicherer Abfolgen** der Trias-, Jura- und Kreidezeit noch erhöhen. An diesen Gesteinshorizonten findet sich ein Großteil der Almen. Die Landschaft ist weitgehend geprägt
# durch so genannte alte Landoberflächen, die plateauartig ausgebildet sind, und **auf denen sich vielfach Gletscherablagerungen
# (Moränen) finden. Moränen und Hangschutt bedecken teilweise die Hänge, in den Kalkalpen sind Schuttreißen prägend und die Täler sind durch junge Talverfüllungen gekennzeichnet**.
#
# Das Einzugsgebiet der Großache ist heute unvergletschert, was aufgrund der geringen Höhen der Gebirgsketten nicht überrascht. Das Blockgletscherinventar Tirols zeigt jedoch, dass in Teileinzugsgebieten der Großache Blockgletscher vorhanden sind. Definitionsgemäß sind Blockgletscher lappen- bis zungenförmige Körper aus gefrorenem Lockermaterial (Hangschutt, Moräne) und Eislinsen oder Eiskörpern, die sich deutlich von ihrer Umgebung abheben und sich langsam hangabwärts bewegen. Blockgletscher sind Erscheinungen des alpinen Permafrostes, können aber auch aus zurückschmelzenden, schuttbedeckten Kargletschern entstehen.
#
# **Im Einzugsgebiet der Großache konnten 16 Blockgletscher identifiziert werden (Institut für Geologie der Universität Innsbruck)**
#
# Quelle: [pdf zum Pegel](https://www.tirol.gv.at/fileadmin/themen/umwelt/wasserkreislauf/wasserstand/downloads/Tafeln_Koessen_Huette.pdf)
#
# weiteres zu Blockgletschern in Tirol:
#
# https://www.uibk.ac.at/afo/publikationen/4.-afo-buch-inhalt.html

# %% [markdown]
# Greenpeace Gletscher: https://www.greenpeace.de/themen/klimawandel/folgen-des-klimawandels/berge-ohne-eis-die-gletscher-schmelzen

# %% [markdown]
# ### Blockgletscher, Permafrostböden, Moränen, Geröll und Schutthalden, etc.
#
# Möglicherweise aussschlaggebend für zum Teil hohe Sedimentfrachten, aber kaum kartiert.
#
# [Blockgletscher](https://www.wikiwand.com/de/Blockgletscher), nicht im CLC oder DKM...

# %%
import pandas as pd

# %%
import sys
sys.path.append('d:\\Projekte\\Innprojekt\\GitHub\\development\\helper\\div_functions\\')

# %%
from eigene_plotting_functions import ecdf

# %%
from ehyd_daten_import import ubawien_csvdaten_import

# %%
import sed_q_at_spezial_plot

# %%
from sed_q_at_spezial_plot import SedQPlotATspezial

# %%
# %load_ext autoreload
# %autoreload

# %%
# %matplotlib inline

# %% [markdown]
# # Kössen-Hütte
#
# pegeldaten_ordner = 's:/Projekte/Innprojekt/Gletscher/Daten/'

# %%
koessen_q = ubawien_csvdaten_import(pegeldaten_ordner+'Q-Tagesmittel-202382.csv', None, 'dailyavgQ')

# %%
koessen_sed = ubawien_csvdaten_import(pegeldaten_ordner+'Schwebstoff-Tagesfracht-202382-blaaa.csv', None, 'dailySedFracht')

# %%
koessen = pd.concat([koessen_q, koessen_sed], axis=1, join='inner')

koessen.index = pd.to_datetime(koessen.index) #, errors=coerce

# %%
#koessen[['dailyavgQ', 'dailySedFracht']]

SedQPlotATspezial('Koessen-Huette, Gr. Ache', koessen)
# Out:
# Sediment summary:
# mean of all years:336417.10000000003
# mean of all years where more than 350 days:336417.10000000003
#       SedFrachtJahresSumme  SedFrachtCounts
# 2008              164824.3              366
# 2009              265521.2              365
# 2010              356027.0              365
# 2011              150142.6              365
# 2012              253720.5              366
# 2013              828267.0              365
# Corr coeffs:
# Pearsons:
#                 dailyavgQ  dailySedFracht
# dailyavgQ        1.000000        0.643779
# dailySedFracht   0.643779        1.000000
# Spearman:
#                 dailyavgQ  dailySedFracht
# dailyavgQ         1.00000         0.87131
# dailySedFracht    0.87131         1.00000
# Kendall:
#                 dailyavgQ  dailySedFracht
# dailyavgQ        1.000000        0.684356
# dailySedFracht   0.684356        1.000000
# None
# Plot:

# %%
SedQPlotATspezial('Koessen-Huette, Gr. Ache - 2013', koessen['2013'])
# Out:
# Sediment summary:
# mean of all years:828266.9999999998
# mean of all years where more than 350 days:828266.9999999998
#       SedFrachtJahresSumme  SedFrachtCounts
# 2013              828267.0              365
# Corr coeffs:
# Pearsons:
#                 dailyavgQ  dailySedFracht
# dailyavgQ        1.000000        0.859826
# dailySedFracht   0.859826        1.000000
# Spearman:
#                 dailyavgQ  dailySedFracht
# dailyavgQ        1.000000        0.809909
# dailySedFracht   0.809909        1.000000
# Kendall:
#                 dailyavgQ  dailySedFracht
# dailyavgQ         1.00000         0.62887
# dailySedFracht    0.62887         1.00000
# None
# Plot:

# %%
koessen['2013-Feb']
# Out:
#             dailyavgQ  dailySedFracht
# Datum
# 2013-02-01      17.27            13.0
# 2013-02-02      34.68            80.2
# 2013-02-13      16.96             8.9
# 2013-02-14      16.59             7.3
# 2013-02-15      16.72            10.7
# 2013-02-16      16.58            14.4
# 2013-02-17      16.15            10.7
# 2013-02-18      15.80             9.7
# 2013-02-19      15.46            10.1
# 2013-02-20      15.38             9.8
# 2013-02-21      14.70             7.6
# 2013-02-22      14.49             4.8
# 2013-02-23      14.28             3.6
# 2013-02-24      14.19             2.7
# 2013-02-25      14.09             2.7
# 2013-02-26      13.87             3.3
# 2013-02-27      13.93             3.9
# 2013-02-28      14.37             5.3
# 2013-02-03      15.36             8.0
# 2013-02-04      20.93            10.3
# 2013-02-05      55.10          1507.8
# 2013-02-06     542.86        481481.8
# 2013-02-07      28.07           190.9
# ...
